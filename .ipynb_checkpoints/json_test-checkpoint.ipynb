# %%
from pyinaturalist import *
import json 
import pandas as pd
import time
from sqlalchemy import create_engine
from connection_string import connection_string

# %%
observationsSep = get_observations(place_id=23, per_page=200, threatened=True, quality_grade='research', month=9)

# %%
observationsSep['results'][1]['taxon']
# Out:
# {
#     'is_active': True,
#     'ancestry': '48460/1/2/355675/3/71261/5067/5085',
#     'min_species_ancestry': '48460,1,2,355675,3,71261,5067,5085,5112',
#     'endemic': False,
#     'iconic_taxon_id': 3,
#     'min_species_taxon_id': 5112,
#     'threatened': True,
#     'rank_level': 10,
#     'introduced': False,
#     'native': True,
#     'parent_id': 5085,
#     'name': 'Accipiter cooperii',
#     'rank': 'species',
#     'extinct': False,
#     'id': 5112,
#     'ancestor_ids': [48460, 1, 2, 355675, 3, 71261, 5067, 5085, 5112],
#     'photos_locked': False,
#     'taxon_schemes_count': 10,
#     'wikipedia_url': "http://en.wikipedia.org/wiki/Cooper's_hawk",
#     'current_synonymous_taxon_ids': None,
#     'created_at': '2008-03-13T02:47:18+00:00',
#     'taxon_changes_count': 1,
#     'complete_species_count': None,
#     'universal_search_rank': 44504,
#     'observations_count': 44504,
#     'flag_counts': {'resolved': 0, 'unresolved': 1},
#     'atlas_id': None,
#     'complete_rank': 'subspecies',
#     'default_photo': {
#         'id': 548218,
#         'license_code': 'cc-by-nc-nd',
#         'attribution': '(c) Jim Johnson, some rights reserved (CC BY-NC-ND)',
#         'url': 'https://inaturalist-open-data.s3.amazonaws.com/photos/548218/square.jpg?1382312939',
#         'original_dimensions': {'height': 700, 'width': 540},
#         'flags': [],
#         'square_url': 'https://inaturalist-open-data.s3.amazonaws.com/photos/548218/square.jpg?1382312939',
#         'medium_url': 'https://inaturalist-open-data.s3.amazonaws.com/photos/548218/medium.jpg?1382312939'
#     },
#     'iconic_taxon_name': 'Aves',
#     'preferred_common_name': "Cooper's Hawk",
#     'conservation_status': {
#         'place_id': 23,
#         'source_id': 8,
#         'user_id': None,
#         'authority': 'NatureServe',
#         'status': 's3s4',
#         'status_name': 'vulnerable',
#         'geoprivacy': None,
#         'iucn': 30
#     },
#     'establishment_means': {
#         'id': 293735,
#         'place_id': 23,
#         'user_id': None,
#         'occurrence_status_level': None,
#         'establishment_means': 'native'
#     },
#     'preferred_establishment_means': 'native'
# }

# %%
dfSep = pd.DataFrame(observationsSep['results'])
dfSep['iconic_taxon_name'] = ""
i = 0
for dict in dfSep['taxon']:
    dfSep.at[i,'iconic_taxon_name'] = dict['iconic_taxon_name']
    i = i+1
dfSep.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quality_grade</th>
#       <th>time_observed_at</th>
#       <th>taxon_geoprivacy</th>
#       <th>annotations</th>
#       <th>uuid</th>
#       <th>id</th>
#       <th>cached_votes_total</th>
#       <th>identifications_most_agree</th>
#       <th>species_guess</th>
#       <th>identifications_most_disagree</th>
#       <th>...</th>
#       <th>faves</th>
#       <th>non_owner_ids</th>
#       <th>observed_on</th>
#       <th>observed_on_details</th>
#       <th>created_at_details</th>
#       <th>created_time_zone</th>
#       <th>observed_time_zone</th>
#       <th>time_zone_offset</th>
#       <th>observed_on_string</th>
#       <th>iconic_taxon_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>research</td>
#       <td>2021-09-23T13:45:00-04:00</td>
#       <td>None</td>
#       <td>[{'user_id': 2182806, 'concatenated_attr_val':...</td>
#       <td>574edc70-e78a-45a4-8fb4-0e0048fff787</td>
#       <td>97098046</td>
#       <td>0</td>
#       <td>True</td>
#       <td>Gray Hairstreak</td>
#       <td>False</td>
#       <td>...</td>
#       <td>[]</td>
#       <td>[{'hidden': False, 'disagreement': False, 'fla...</td>
#       <td>2021-09-23 13:45:00-05:00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Insecta</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>research</td>
#       <td>2021-09-30T16:49:32-04:00</td>
#       <td>open</td>
#       <td>[]</td>
#       <td>7a596abc-b885-4c14-9262-6c7d01111220</td>
#       <td>97081144</td>
#       <td>0</td>
#       <td>True</td>
#       <td>Gulf Fritillary</td>
#       <td>False</td>
#       <td>...</td>
#       <td>[]</td>
#       <td>[{'hidden': False, 'disagreement': False, 'fla...</td>
#       <td>2021-09-30 16:49:32-05:00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Insecta</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>research</td>
#       <td>2021-09-19T10:56:15-04:00</td>
#       <td>None</td>
#       <td>[]</td>
#       <td>4a87371e-9848-484d-bfdf-f760491b0157</td>
#       <td>97074099</td>
#       <td>0</td>
#       <td>True</td>
#       <td>Hairy cluster-vine</td>
#       <td>False</td>
#       <td>...</td>
#       <td>[]</td>
#       <td>[{'hidden': False, 'disagreement': False, 'fla...</td>
#       <td>2021-09-19 10:56:15-05:00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Plantae</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>research</td>
#       <td>2021-09-30T13:17:00-04:00</td>
#       <td>open</td>
#       <td>[]</td>
#       <td>7f372b28-350c-410a-a037-348281c28c05</td>
#       <td>97073279</td>
#       <td>0</td>
#       <td>True</td>
#       <td>Barking Treefrog</td>
#       <td>False</td>
#       <td>...</td>
#       <td>[]</td>
#       <td>[{'hidden': False, 'disagreement': False, 'fla...</td>
#       <td>2021-09-30 13:17:00-05:00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Amphibia</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>research</td>
#       <td>2021-09-28T14:45:00-04:00</td>
#       <td>None</td>
#       <td>[]</td>
#       <td>eae85fc4-c99a-4c9f-be93-ccbdf08d0955</td>
#       <td>97073277</td>
#       <td>0</td>
#       <td>True</td>
#       <td>Southern Slender Ladies'-tresses</td>
#       <td>False</td>
#       <td>...</td>
#       <td>[]</td>
#       <td>[{'hidden': False, 'disagreement': False, 'fla...</td>
#       <td>2021-09-28 14:45:00-05:00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Plantae</td>
#     </tr>
#   </tbody>
# </table>
# <p>5 rows × 68 columns</p>
# </div>
